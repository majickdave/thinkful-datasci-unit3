# %%
import pandas as pd

df = pd.read_csv("data/2008.csv.bz2")

df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 0        2225            WN        335        ...            4.0      8.0
# 1        1000            WN       3231        ...            5.0     10.0
# 2         750            WN        448        ...            3.0     17.0
# 3        1100            WN       1746        ...            3.0      7.0
# 4        1925            WN       3920        ...            3.0     10.0
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7009728 entries, 0 to 7009727
# Data columns (total 29 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin               object
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# ...

# %%
data = df[df.ArrDelay + df.DepDelay > 30]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

np.log(data[['DepDelay', 'ArrDelay']][data[['DepDelay', 'ArrDelay']] > 0]).plot.hist(alpha=0.5)

plt.show()

# %% [markdown]
# # you can almost see that arrival delay is a bit higher in frequency
